# %%
import yfinance as yf
import ta
import pandas as pd
from datetime import datetime, timedelta

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import accuracy_score, classification_report
import joblib

import xgboost as xgb


def build_training_data(ticker: str, lookahead_days: int = 5):
    end = datetime.today()
    start = end - timedelta(days=365*3)  # 3 years
    df = yf.download(
        ticker,
        start=start.strftime("%Y-%m-%d"),
        end=end.strftime("%Y-%m-%d"),
        progress=False,
        auto_adjust=True   # avoid yfinance warning, adjusted prices
    )

    if df.empty:
        return pd.DataFrame()

    close = df_raw["Close"][ticker]
    volume = df_raw["Volume"][ticker]

    features = pd.DataFrame(index=df.index)

    # Indicators
    features["RSI"] = ta.momentum.RSIIndicator(close).rsi()

    macd = ta.trend.MACD(close)
    features["MACD_diff"] = macd.macd_diff()

    sma50 = close.rolling(50).mean()
    sma200 = close.rolling(200).mean()
    features["SMA50_gt_SMA200"] = (sma50 > sma200).astype(int)

    high20 = close.rolling(20).max()
    features["BreakoutUp"] = (close > high20).astype(int)

    low20 = close.rolling(20).min()
    features["BreakoutDown"] = (close < low20).astype(int)

    avg_vol = volume.rolling(20).mean()
    std_vol = volume.rolling(20).std()
    features["HighVolume"] = (volume > avg_vol + 2 * std_vol).astype(int)

    # Target
    future_price = close.shift(-lookahead_days)
    features["Target"] = (future_price > close).astype(int)

    return features.dropna()


def train_model_cv(ticker, lookahead_days=5, n_splits=5, model_type="logistic", verbose=False):
    data = build_training_data(ticker, lookahead_days)
    if data.empty:
        raise ValueError("No training data available.")

    X = data.drop(columns=["Target"])
    y = data["Target"]

    if model_type == "logistic":
        model = Pipeline([
            ("scaler", StandardScaler()),
            ("clf", LogisticRegression(max_iter=500))
        ])
    elif model_type == "xgboost":
        model = xgb.XGBClassifier(
            n_estimators=200,
            max_depth=4,
            learning_rate=0.05,
            subsample=0.8,
            colsample_bytree=0.8,
            eval_metric="logloss",
        )
    else:
        raise ValueError("model_type must be 'logistic' or 'xgboost'")
    
    # TimeSeries CV
    tscv = TimeSeriesSplit(n_splits=n_splits)
    scores = []

    if verbose:
        print(f"\n {model_type}: TimeSeries Cross-Validation ({n_splits} folds)")
        print("=" * 50)

    for fold, (train_idx, test_idx) in enumerate(tscv.split(X), 1):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        acc = accuracy_score(y_test, preds)
        scores.append(acc)

        if verbose:
            print(f"Fold {fold}: Accuracy = {acc:.4f}")
            print(classification_report(y_test, preds, zero_division=0))

    avg_acc = sum(scores) / len(scores)
    if verbose:
        print("=" * 50)
        print(f"Average Accuracy across folds: {avg_acc:.4f}")

    # Retrain on all data before saving
    model.fit(X, y)
    joblib.dump((model, list(X.columns)), f"./predict/models/{model_type}_{ticker}_model.pkl")

    return model, X.columns

# %%
def get_model_decision(ticker: str, model_path=None):
    # Load trained model
    if model_path is None:
        model_path = f"{ticker}_model.pkl"
    model, feature_names = joblib.load(model_path)

    # Fetch latest data
    end = datetime.today()
    start = end - timedelta(days=365)
    df = yf.download(ticker, start=start.strftime("%Y-%m-%d"), end=end.strftime("%Y-%m-%d"), progress=False, auto_adjust=True)

    if df.empty:
        return "NOT NOW", {}

    close = df_raw["Close"][ticker]
    volume = df_raw["Volume"][ticker]

    # Build feature row (same as training features)
    features = {}

    features["RSI"] = ta.momentum.RSIIndicator(close).rsi().iloc[-1]

    macd = ta.trend.MACD(close)
    features["MACD_diff"] = macd.macd_diff().iloc[-1]

    sma50 = close.rolling(50).mean().iloc[-1]
    sma200 = close.rolling(200).mean().iloc[-1]
    features["SMA50_gt_SMA200"] = int(sma50 > sma200)

    last_price = close.iloc[-1]
    high20 = close.rolling(20).max().iloc[-1]
    features["BreakoutUp"] = int(last_price > high20)

    low20 = close.rolling(20).min().iloc[-1]
    features["BreakoutDown"] = int(last_price < low20)

    last_vol = volume.iloc[-1]
    avg_vol = volume.rolling(20).mean().iloc[-1]
    std_vol = volume.rolling(20).std().iloc[-1]
    features["HighVolume"] = int(last_vol > avg_vol + 2 * std_vol)

    # Convert to DataFrame in correct column order
    X_live = pd.DataFrame([features])[feature_names]

    # Predict
    prob = model.predict_proba(X_live)[0, 1]  # probability of "up"
    decision = "BUY" if prob > 0.5 else "NOT BUY"

    return decision, features, prob

# %%
# Logistic Regression
log_model, log_features = train_model_cv("AAPL", lookahead_days=5, model_type="logistic")

# XGBoost
xgb_model, xgb_features = train_model_cv("AAPL", lookahead_days=5, model_type="xgboost")

# %%
# Train once
ticker = "AAPL"
model, features = train_model_cv(ticker, lookahead_days=5, model_type="logistic")

# Predict live decision
decision, feat_values, prob = get_model_decision(ticker)
print("Decision:", decision)
print("Probability of going up:", prob)
print("Features:", feat_values)
# Out:
#  logistic: TimeSeries Cross-Validation (5 folds)
# ==================================================
# Fold 1: Accuracy = 0.6134
#               precision    recall  f1-score   support
#
#            0       0.62      0.10      0.18        48
#            1       0.61      0.96      0.75        71
#
#     accuracy                           0.61       119
#    macro avg       0.62      0.53      0.46       119
# weighted avg       0.62      0.61      0.52       119
#
# Fold 2: Accuracy = 0.4286
#               precision    recall  f1-score   support
#
#            0       0.42      0.41      0.41        59
#            1       0.44      0.45      0.44        60
#
#     accuracy                           0.43       119
#    macro avg       0.43      0.43      0.43       119
# weighted avg       0.43      0.43      0.43       119
#
# Fold 3: Accuracy = 0.6218
#               precision    recall  f1-score   support
#
#            0       0.60      0.07      0.12        46
#            1       0.62      0.97      0.76        73
#
#     accuracy                           0.62       119
#    macro avg       0.61      0.52      0.44       119
# weighted avg       0.61      0.62      0.51       119
#
# Fold 4: Accuracy = 0.5462
#               precision    recall  f1-score   support
#
#            0       0.50      0.26      0.34        54
#            1       0.56      0.78      0.65        65
#
#     accuracy                           0.55       119
#    macro avg       0.53      0.52      0.50       119
# weighted avg       0.53      0.55      0.51       119
#
# Fold 5: Accuracy = 0.5042
#               precision    recall  f1-score   support
#
#            0       0.57      0.07      0.12        60
#            1       0.50      0.95      0.65        59
#
#     accuracy                           0.50       119
#    macro avg       0.54      0.51      0.39       119
# weighted avg       0.54      0.50      0.38       119
#
# ==================================================
# Average Accuracy across folds: 0.5429
# Decision: BUY
# Probability of going up: 0.629559618953061
# Features: {'RSI': np.float64(58.22666098365983), 'MACD_diff': np.float64(0.314546796638866), 'SMA50_gt_SMA200': 0, 'BreakoutUp': 0, 'BreakoutDown': 0, 'HighVolume': 0}

# %%
info.get("trailingPE", None)
# Out:
# 34.613983

# %%
import pandas as pd

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
tables = pd.read_html(url, header=0)
tickers = tables[0]['Symbol'].tolist()[:10]

# %%
def get_fundamentals(ticker, get_train, lookahead_days=90):
    t = yf.Ticker(ticker)
    inc = t.quarterly_financials.T
    bal = t.quarterly_balance_sheet.T
    cf  = t.quarterly_cashflow.T

    df_raw = pd.concat([inc, bal, cf], axis=1)

    # Profitability Ratios
    df_extract = pd.DataFrame()
    df_extract['Gross_Margin'] = df_raw['Gross Profit'] / df_raw['Total Revenue']
    df_extract['Operating_Margin'] = df_raw['Operating Income'] / df_raw['Total Revenue']
    df_extract['Net_Margin'] = df_raw['Net Income'] / df_raw['Total Revenue']
    df_extract['EBITDA_Margin'] = df_raw['EBITDA'] / df_raw['Total Revenue']

    # Growth Ratios (YoY)
    df_extract['Revenue_Growth'] = df_raw['Total Revenue'].pct_change(fill_method=None)
    df_extract['Net_Income_Growth'] = df_raw['Net Income'].pct_change(fill_method=None)
    df_extract['EPS_Growth'] = df_raw['Diluted EPS'].pct_change(fill_method=None)

    # Return Ratios
    df_extract['ROE'] = df_raw['Net Income'] / df_raw['Stockholders Equity']
    df_extract['ROA'] = df_raw['Net Income'] / df_raw['Total Assets']
    df_extract['ROIC'] = df_raw['EBIT'] / (df_raw['Total Debt'] + df_raw['Stockholders Equity'] - df_raw['Cash And Cash Equivalents'])

    # Leverage Ratios
    df_extract['Debt_to_Equity'] = df_raw['Total Debt'] / df_raw['Stockholders Equity']
    df_extract['Net_Debt_to_EBITDA'] = df_raw['Net Debt'] / df_raw['EBITDA']

    # Liquidity Ratios
    df_extract['Current_Ratio'] = df_raw['Current Assets'] / df_raw['Current Liabilities']
    df_extract['Quick_Ratio'] = (df_raw['Current Assets'] - df_raw['Inventory']) / df_raw['Current Liabilities']

    # Cash Flow Metrics
    df_extract['FCF_to_Sales'] = df_raw['Free Cash Flow'] / df_raw['Total Revenue']
    df_extract['FCF_yield'] = df_raw['Free Cash Flow'] / df_raw['Stockholders Equity']

    df_extract['Report_Date'] = df_extract.index

    start_date = df_extract['Report_Date'].min()
    end_date = df_extract['Report_Date'].max() + pd.Timedelta(days=lookahead_days+30)
    prices = yf.download(ticker, start=start_date, end=end_date, progress=False, auto_adjust=True)["Close"][ticker]

    if get_train:
        df_extract['Price_Ahead'] = df_extract['Report_Date'].apply(
            lambda x: prices.get(x + pd.Timedelta(days=lookahead_days))
        )
        df_extract['Price_Today'] = df_extract['Report_Date'].apply(
            lambda x: prices.get(x)
        )
        df_extract = df_extract.dropna()

        df_extract['Price_Increase'] = (df_extract['Price_Ahead'] > df_extract['Price_Today']).astype(int)

        df_extract = df_extract.drop(columns=['Report_Date', 'Price_Today', 'Price_Ahead'])
    
    else:
        df_extract = df_extract.drop(columns=['Report_Date'])
        df_extract = df_extract.dropna()
    
    return df_extract

# %%
df_train = pd.DataFrame()
for ticker in tickers:
    try:
        df_fund = get_fundamentals(ticker, lookahead_days=90)
        df_train = pd.concat([df_train, df_fund], ignore_index=True)
    except Exception as e:
        pass
        # print(f"Error processing {ticker}: {e}")
# Out:
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31
1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    97.650246    88.870201               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31  1223.680054  1180.910034               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    34.650002    29.639999               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    56.096767    47.707573               0
#             Price_Today  Price_Ahead  Price_Increase
# 2025-02-28    93.420311    96.708977               1
# 2024-05-31   124.309418    95.125137               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   419.196564   374.087158               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   119.129997       114.18               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    56.370346     60.31834               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    58.904144    67.379509               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    24.210369    26.848616               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   459.796875   436.654724               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-07-31   124.468269   119.347565               0
# 2024-10-31   113.510117   118.936073               1
# 2025-01-31   120.735741    89.296402               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    36.827919    48.055023               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    70.533401    70.320992               0
#             Price_Today  Price_Ahead  Price_Increase
# 2025-02-28    78.508263    61.034386               0
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
#             Price_Today  Price_Ahead  Price_Increase
# 2024-10-31   245.146027   216.363800               0
# 2025-01-31   218.597214   189.666565               0
# 2025-04-30   188.879440   220.210007               1
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31        25.73    18.959999               0
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   115.697441   119.836411               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-04-30    86.367622   111.554749               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   205.872528   189.178024               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    79.053329    95.505333               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31     48.88612    49.086029               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    84.500793    82.098862               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    63.049999    40.689999               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    96.869194    96.756302               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    91.404976   102.264076               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   103.002144    96.718079               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   222.218262   196.739548               0
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   632.750549   606.144409               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    99.853432    87.004738               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   149.091431   148.312637               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    25.175562     24.44385               0
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    118.40551   157.543869               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   110.742447   121.106735               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    82.280685    93.414375               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   337.095947   315.863922               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   117.239571   107.949135               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    31.940744    35.819374               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   164.476868   168.213928               1
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   108.435966   102.579185               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    315.74704   254.016739               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   151.883743    152.69278               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   148.718338   167.614166               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   114.051018   131.210312               1
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
# Empty DataFrame
# Columns: [Price_Today, Price_Ahead, Price_Increase]
# Index: []
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   199.648209   241.011032               1
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31    227.20961   222.900269               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   111.379723   105.643578               0
#             Price_Today  Price_Ahead  Price_Increase
# 2024-12-31   282.227966   256.300079               0

# %%
def train_fundamentals_model():

    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url, header=0)
    tickers = tables[0]['Symbol'].tolist()

    df_train = pd.DataFrame()
    for ticker in tickers:
        try:
            df_fund = get_fundamentals(ticker, lookahead_days=90)
            df_train = pd.concat([df_train, df_fund], ignore_index=True)
        except Exception as e:
            pass
            # print(f"Error processing {ticker}: {e}")

    X = df_train.drop(columns=['Price_Increase'])

    X.replace([np.inf, -np.inf], np.nan, inplace=True)
    X.fillna(X.median(), inplace=True)

    y = df_train['Price_Increase']

    # Define pipeline: scaler + classifier
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('clf', LogisticRegression(random_state=42, max_iter=1000, class_weight='balanced'))
    ])

    # K-Fold Cross Validation
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    accuracies = []

    for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        
        # Train pipeline
        pipeline.fit(X_train, y_train)
        
        # Predict
        y_pred = pipeline.predict(X_test)
        
        # Evaluate
        acc = accuracy_score(y_test, y_pred)
        accuracies.append(acc)
        
        print(f"Fold {fold} Accuracy: {acc:.4f}")
        print(classification_report(y_test, y_pred, zero_division=0))

    print(f"\nAverage Accuracy across folds: {sum(accuracies)/len(accuracies):.4f}")
    
    pipeline.fit(X, y)
    joblib.dump((model, list(X.columns)), f"./machine_learning/models/fundamentals_model.pkl")

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report

# Features and target
X = df_train.drop(columns=['Price_Increase'])

X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.fillna(X.median(), inplace=True)

y = df_train['Price_Increase']

# Define pipeline: scaler + classifier
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('clf', LogisticRegression(random_state=42, max_iter=1000, class_weight='balanced'))
])

# K-Fold Cross Validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
accuracies = []

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    # Train pipeline
    pipeline.fit(X_train, y_train)
    
    # Predict
    y_pred = pipeline.predict(X_test)
    
    # Evaluate
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    
    print(f"Fold {fold} Accuracy: {acc:.4f}")
    print(classification_report(y_test, y_pred, zero_division=0))

pipeline.fit(X, y)
joblib.dump((model, list(X.columns)), f"./machine_learning/models/fundamentals_model.pkl")
# Out:
# Fold 1 Accuracy: 0.5686
#               precision    recall  f1-score   support
#
#            0       0.57      0.52      0.54        25
#            1       0.57      0.62      0.59        26
#
#     accuracy                           0.57        51
#    macro avg       0.57      0.57      0.57        51
# weighted avg       0.57      0.57      0.57        51
#
# Fold 2 Accuracy: 0.6078
#               precision    recall  f1-score   support
#
#            0       0.57      0.84      0.68        25
#            1       0.71      0.38      0.50        26
#
#     accuracy                           0.61        51
#    macro avg       0.64      0.61      0.59        51
# weighted avg       0.64      0.61      0.59        51
#
# Fold 3 Accuracy: 0.5882
#               precision    recall  f1-score   support
#
#            0       0.58      0.60      0.59        25
#            1       0.60      0.58      0.59        26
#
#     accuracy                           0.59        51
#    macro avg       0.59      0.59      0.59        51
# weighted avg       0.59      0.59      0.59        51
#
# Fold 4 Accuracy: 0.5600
#               precision    recall  f1-score   support
#
#            0       0.53      0.67      0.59        24
#            1       0.60      0.46      0.52        26
#
#     accuracy                           0.56        50
#    macro avg       0.57      0.56      0.56        50
# weighted avg       0.57      0.56      0.56        50
#
# Fold 5 Accuracy: 0.5600
#               precision    recall  f1-score   support
#
#            0       0.57      0.48      0.52        25
#            1       0.55      0.64      0.59        25
#
#     accuracy                           0.56        50
#    macro avg       0.56      0.56      0.56        50
# weighted avg       0.56      0.56      0.56        50
#
#
# Average Accuracy across folds: 0.5769

# %%
X_test = get_fundamentals("MSFT", get_train=False).iloc[[-1]]
prob = pipeline.predict_proba(X_test)[:, 1]
label = pipeline.predict(X_test)

# %%
prob, label
# Out:
# (array([0.62687539]), array([1]))

# %%
# result = df_raw[['Report_Date']].copy()
# result['Pred_Prob'] = prob
# result['Pred_Label'] = label

# %%
X_test
# Out:
#      Gross_Margin  Operating_Margin  Net_Margin  EBITDA_Margin  \
# 7        0.519185          0.179856    0.128897       0.217026
# 11       0.465164          0.226434    0.153689       0.472336
# 15       0.366002          0.266224    0.219832       0.319160
# 19       0.590260          0.229121    0.161489       0.423594
# 22       0.468825          0.344586    0.292277       0.369364
# 28       0.278721          0.128060    0.079608       0.159583
# 40       0.640529          0.351857    0.307670       0.518714
# 46       0.294374          0.112516   -0.001308       0.083297
# 47       0.312771          0.142857    0.078644       0.173160
# 51       0.351807          0.093287   -0.013425       0.165232
# 57       0.283521          0.047193   -0.215151      -0.086233
# 64       0.655735          0.228709    0.176055       0.281009
# 68       0.603033          0.227503    0.149444       0.240849
# 75       0.684358          0.188660    0.108117       0.280191
# 86       0.370278          0.197931    0.114990       0.268680
# 89       0.243450          0.096402    0.069115       0.135306
# 90       0.217803          0.068456    0.046458       0.101986
# 237      0.383680  -0.316936
# 241      0.068360   0.021813
# 243      0.178229   0.076220

# %%
def prepare_financial_ratios(df_raw):
    """
    Input: df_raw containing raw financial data for a ticker
    Output: DataFrame of features ready for the model
    """
    df = df_raw.copy()
    
    # Calculate ratios (must match training features)
    df['Gross_Margin'] = df['Gross Profit'] / df['Total Revenue']
    df['Operating_Margin'] = df['Operating Income'] / df['Total Revenue']
    df['Net_Margin'] = df['Net Income'] / df['Total Revenue']
    df['EBITDA_Margin'] = df['EBITDA'] / df['Total Revenue']
    
    df['Revenue_Growth'] = df['Total Revenue'].pct_change().fillna(0)
    df['Net_Income_Growth'] = df['Net Income'].pct_change().fillna(0)
    df['EPS_Growth'] = df['Diluted EPS'].pct_change(fill_method=None).fillna(0)
    
    df['ROE'] = df['Net Income'] / df['Stockholders Equity']
    df['ROA'] = df['Net Income'] / df['Total Assets']
    df['ROIC'] = df['EBIT'] / (df['Total Debt'] + df['Stockholders Equity'] - df['Cash And Cash Equivalents'])
    
    df['Debt_to_Equity'] = df['Total Debt'] / df['Stockholders Equity']
    df['Net_Debt_to_EBITDA'] = df['Net Debt'] / df['EBITDA']
    
    df['Current_Ratio'] = df['Current Assets'] / df['Current Liabilities']
    df['Quick_Ratio'] = (df['Current Assets'] - df['Inventory']) / df['Current Liabilities']
    
    df['FCF_to_Sales'] = df['Free Cash Flow'] / df['Total Revenue']
    df['FCF_yield'] = df['Free Cash Flow'] / df['Stockholders Equity']
    
    # Keep only features used in training
    feature_cols = ['Gross_Margin','Operating_Margin','Net_Margin','EBITDA_Margin',
                    'Revenue_Growth','Net_Income_Growth','EPS_Growth','ROE','ROA','ROIC',
                    'Debt_to_Equity','Net_Debt_to_EBITDA','Current_Ratio','Quick_Ratio',
                    'FCF_to_Sales','FCF_yield']
    
    X = df[feature_cols]
    
    # Handle inf/-inf and NaN
    X.replace([np.inf, -np.inf], np.nan, inplace=True)
    X.fillna(X.median(), inplace=True)
    
    return X

def predict_ticker(df_raw, pipeline):
    """
    Input: raw financial data for a ticker, trained pipeline
    Output: DataFrame with prediction probability and label
    """
    X_test = prepare_financial_ratios(df_raw)
    
    # Predict probability of price increase
    prob = pipeline.predict_proba(X_test)[:, 1]
    label = pipeline.predict(X_test)
    
    result = df_raw[['Report_Date']].copy()
    result['Pred_Prob'] = prob
    result['Pred_Label'] = label
    
    return result

# %%
# replace with your financial data extraction
# predictions = predict_ticker(new_ticker_df, pipeline)
# print(predictions)

# %%
new_ticker_df
# Out:
#             Gross_Margin  Operating_Margin  Net_Margin  EBITDA_Margin  \
# 2024-09-30      0.693543          0.465838    0.376107       0.582969
# 2024-12-31      0.686940          0.454575    0.346220       0.528292
# 2025-03-31      0.687166          0.456712    0.368567       0.581038
# 2025-06-30      0.685849          0.449013    0.356262       0.581285
#
#             Revenue_Growth  Net_Income_Growth  EPS_Growth       ROE       ROA  \
# 2024-09-30        0.013256           0.119396    0.118644  0.085732  0.047163
# 2024-12-31        0.061706          -0.022662   -0.021212  0.079645  0.045155
# 2025-03-31        0.006233           0.071180    0.071207  0.080226  0.045899
# 2025-06-30        0.090986           0.054562    0.054913  0.079286  0.043995
#
#                 ROIC  Debt_to_Equity  Net_Debt_to_EBITDA  Current_Ratio  \
# 2024-09-30  0.093955        0.213671            0.634958       1.301441
# 2024-12-31  0.086229        0.205567            0.747241       1.350820
# 2025-03-31  0.090408        0.188160            0.345189       1.371592
# 2025-06-30  0.088895        0.176395            0.290521       1.353446
#
#             Quick_Ratio  FCF_to_Sales  FCF_yield  Price_Increase
# 2024-09-30     1.287326      0.293619   0.066929               0
# 2024-12-31     1.342472      0.093161   0.021431               0
# 2025-03-31     1.364167      0.289713   0.063062               0
# 2025-06-30     1.346804      0.334480   0.074438               0

# %%
get_fundamentals("AAPL", lookahead_days=30)
# Out:
#             Gross_Margin  Operating_Margin  Net_Margin  EBITDA_Margin  \
# 2024-09-30      0.462225          0.311714    0.155230       0.342379
# 2024-12-31      0.468825          0.344586    0.292277       0.369364
# 2025-03-31      0.470506          0.310291    0.259860       0.338196
# 2025-06-30      0.464907          0.299906    0.249202       0.330001
#
#             Revenue_Growth  Net_Income_Growth  EPS_Growth       ROE       ROA  \
# 2024-09-30        0.106707          -0.312943   -0.307143  0.258753  0.040375
# 2024-12-31        0.309386           1.465391    1.474227  0.544204  0.105584
# 2025-03-31       -0.232832          -0.317919   -0.312500  0.370980  0.074811
# 2025-06-30       -0.013874          -0.054318   -0.048485  0.355978  0.070692
#
#                 ROIC  Debt_to_Equity  Net_Debt_to_EBITDA  Current_Ratio  \
# 2024-09-30  0.221430        1.872327            2.359424       0.867313
# 2024-12-31  0.321422        1.449999            1.448423       0.922938
# 2025-03-31  0.216262        1.469938            2.171287       0.820870
# 2025-06-30  0.214858        1.544858            2.108436       0.867992
#
#             Quick_Ratio  FCF_to_Sales  FCF_yield Report_Date  Price_Ahead
# 2024-09-30     0.826007      0.251796   0.419719  2024-09-30   229.034073
# 2024-12-31     0.875067      0.217176   0.404371  2024-12-31   236.749557
# 2025-03-31     0.777507      0.218973   0.312609  2025-03-31   211.981125
# 2025-06-30     0.826006      0.259528   0.370728  2025-06-30   208.813019

# %%
# Profitability Ratios
df_extract = pd.DataFrame()
df_extract['Gross_Margin'] = df_raw['Gross Profit'] / df_raw['Total Revenue']
df_extract['Operating_Margin'] = df_raw['Operating Income'] / df_raw['Total Revenue']
df_extract['Net_Margin'] = df_raw['Net Income'] / df_raw['Total Revenue']
df_extract['EBITDA_Margin'] = df_raw['EBITDA'] / df_raw['Total Revenue']

# Growth Ratios (YoY)
df_extract['Revenue_Growth'] = df_raw['Total Revenue'].pct_change()
df_extract['Net_Income_Growth'] = df_raw['Net Income'].pct_change()
df_extract['EPS_Growth'] = df_raw['Diluted EPS'].pct_change()

# Return Ratios
df_extract['ROE'] = df_raw['Net Income'] / df_raw['Stockholders Equity']
df_extract['ROA'] = df_raw['Net Income'] / df_raw['Total Assets']
df_extract['ROIC'] = df_raw['EBIT'] / (df_raw['Total Debt'] + df_raw['Stockholders Equity'] - df_raw['Cash And Cash Equivalents'])

# Leverage Ratios
df_extract['Debt_to_Equity'] = df_raw['Total Debt'] / df_raw['Stockholders Equity']
df_extract['Net_Debt_to_EBITDA'] = df_raw['Net Debt'] / df_raw['EBITDA']

# Liquidity Ratios
df_extract['Current_Ratio'] = df_raw['Current Assets'] / df_raw['Current Liabilities']
df_extract['Quick_Ratio'] = (df_raw['Current Assets'] - df_raw['Inventory']) / df_raw['Current Liabilities']

# Cash Flow Metrics
df_extract['FCF_to_Sales'] = df_raw['Free Cash Flow'] / df_raw['Total Revenue']
df_extract['FCF_yield'] = df_raw['Free Cash Flow'] / df_raw['Stockholders Equity']

df_extract = df_extract.dropna()

# %%
df_extract.index
# Out:
# DatetimeIndex(['2024-09-30', '2024-12-31', '2025-03-31', '2025-06-30'], dtype='datetime64[ns]', freq='QE-DEC')

# %%
df_extract['Report_Date'] = df_extract.index

# %%
N = 1

start_date = df_extract['Report_Date'].min()
end_date = df_extract['Report_Date'].max() + pd.Timedelta(days=N+30)  # buffer
prices = yf.download(ticker, start=start_date, end=end_date, progress=False, auto_adjust=True)["Close"][ticker]

df_extract['Price_Ahead'] = df_extract['Report_Date'].apply(
    lambda x: prices.get(x + pd.Timedelta(days=N))
)

df_extract = df_extract.dropna()

# %%
df_extract
# Out:
#             Gross_Margin  Operating_Margin  Net_Margin  EBITDA_Margin  \
# 2024-09-30      0.462225          0.311714    0.155230       0.342379
# 2025-03-31      0.470506          0.310291    0.259860       0.338196
# 2025-06-30      0.464907          0.299906    0.249202       0.330001
#
#             Revenue_Growth  Net_Income_Growth  EPS_Growth       ROE       ROA  \
# 2024-09-30        0.106707          -0.312943   -0.307143  0.258753  0.040375
# 2025-03-31       -0.232832          -0.317919   -0.312500  0.370980  0.074811
# 2025-06-30       -0.013874          -0.054318   -0.048485  0.355978  0.070692
#
#                 ROIC  Debt_to_Equity  Net_Debt_to_EBITDA  Current_Ratio  \
# 2024-09-30  0.221430        1.872327            2.359424       0.867313
# 2025-03-31  0.216262        1.469938            2.171287       0.820870
# 2025-06-30  0.214858        1.544858            2.108436       0.867992
#
#             Quick_Ratio  FCF_to_Sales  FCF_yield Report_Date  \
# 2024-09-30     0.826007      0.251796   0.419719  2024-09-30
# 2025-03-31     0.777507      0.218973   0.312609  2025-03-31
# 2025-06-30     0.826006      0.259528   0.370728  2025-06-30
#
#             Price_N_Days_Ahead  Price_Ahead
# 2024-09-30          225.162094   225.162094
# 2025-03-31          222.645020   222.645020
# 2025-06-30          207.584412   207.584412

# %%
prices.get("2024-10-01")
# Out:
# np.float64(225.16209411621094)

# %%
df_extract
# Out:
#             Gross_Margin  Operating_Margin  Net_Margin  EBITDA_Margin  \
# 2024-09-30      0.462225          0.311714    0.155230       0.342379
# 2024-12-31      0.468825          0.344586    0.292277       0.369364
# 2025-03-31      0.470506          0.310291    0.259860       0.338196
# 2025-06-30      0.464907          0.299906    0.249202       0.330001
#
#             Revenue_Growth  Net_Income_Growth  EPS_Growth       ROE       ROA  \
# 2024-09-30        0.106707          -0.312943   -0.307143  0.258753  0.040375
# 2024-12-31        0.309386           1.465391    1.474227  0.544204  0.105584
# 2025-03-31       -0.232832          -0.317919   -0.312500  0.370980  0.074811
# 2025-06-30       -0.013874          -0.054318   -0.048485  0.355978  0.070692
#
#                 ROIC  Debt_to_Equity  Net_Debt_to_EBITDA  Current_Ratio  \
# 2024-09-30  0.221430        1.872327            2.359424       0.867313
# 2024-12-31  0.321422        1.449999            1.448423       0.922938
# 2025-03-31  0.216262        1.469938            2.171287       0.820870
# 2025-06-30  0.214858        1.544858            2.108436       0.867992
#
#             Quick_Ratio  FCF_to_Sales  FCF_yield Report_Date  \
# 2024-09-30     0.826007      0.251796   0.419719  2024-09-30
# 2024-12-31     0.875067      0.217176   0.404371  2024-12-31
# 2025-03-31     0.777507      0.218973   0.312609  2025-03-31
# 2025-06-30     0.826006      0.259528   0.370728  2025-06-30
#
#             Price_N_Days_Ahead
# 2024-09-30                 NaN
# 2024-12-31          221.587616
# 2025-03-31                 NaN
# 2025-06-30                 NaN

# %%
df_extract['Price_N_Days_Ahead'] = df_raw['Report_Date'].apply(
    lambda x: prices.get(x + pd.Timedelta(days=N), pd.NA)
)

# %%
prices
# Out:
# Ticker            AAPL
# Date
# 2024-09-30  231.920639
# 2024-10-01  225.162094
# 2024-10-02  225.729462
# 2024-10-03  224.624588
# 2024-10-04  225.749359
# ...                ...
# 2025-08-18  230.889999
# 2025-08-19  230.559998
# 2025-08-20  226.009995
# 2025-08-21  224.899994
# 2025-08-22  227.759995
#
# [225 rows x 1 columns]

# %%
all_feats = []
for ticker in tickers:
    feats = get_fundamentals(ticker)
    all_feats.append(feats)
all_feats = pd.concat(all_feats, ignore_index=True)

# all_feats["target"] = all_feats.apply(lambda r: make_target(r["ticker"], r["date"]), axis=1)
# Out:
# Tax Effect Of Unusual Items               NaN
# Tax Rate For Calcs                        NaN
# Normalized EBITDA                         NaN
# Total Unusual Items                       NaN
# Total Unusual Items Excluding Goodwill    NaN
#                                          ...
# Depreciation And Amortization             NaN
# Operating Gains Losses                    NaN
# Pension And Employee Benefit Expense      NaN
# Gain Loss On Sale Of Business             0.0
# Net Income From Continuing Operations     NaN
# Name: 2023-12-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items              NaN
# Tax Rate For Calcs                       NaN
# Normalized EBITDA                        NaN
# Total Unusual Items                      NaN
# Total Unusual Items Excluding Goodwill   NaN
#                                           ..
# Depreciation And Amortization            NaN
# Operating Gains Losses                   NaN
# Pension And Employee Benefit Expense     NaN
# Gain Loss On Sale Of Business            NaN
# Net Income From Continuing Operations    NaN
# Name: 2024-03-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items               1.602720e+08
# Tax Rate For Calcs                        1.440000e-01
# Normalized EBITDA                         9.200000e+08
# Total Unusual Items                       1.113000e+09
# Total Unusual Items Excluding Goodwill    1.113000e+09
#                                               ...
# Depreciation And Amortization             3.010000e+08
# Operating Gains Losses                    8.440000e+08
# Pension And Employee Benefit Expense      8.440000e+08
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations     1.151000e+09
# Name: 2024-06-30 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items               1.179430e+08
# Tax Rate For Calcs                        2.030000e-01
# Normalized EBITDA                         1.726000e+09
# Total Unusual Items                       5.810000e+08
# Total Unusual Items Excluding Goodwill    5.810000e+08
#                                               ...
# Depreciation And Amortization             3.100000e+08
# Operating Gains Losses                    5.500000e+07
# Pension And Employee Benefit Expense      5.500000e+07
# Gain Loss On Sale Of Business             0.000000e+00
# Net Income From Continuing Operations     1.376000e+09
# Name: 2024-09-30 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items              -5.652174e+06
# Tax Rate For Calcs                        4.347800e-02
# Normalized EBITDA                         1.463000e+09
# Total Unusual Items                      -1.300000e+08
# Total Unusual Items Excluding Goodwill   -1.300000e+08
#                                               ...
# Depreciation And Amortization             3.220000e+08
# Operating Gains Losses                    8.200000e+07
# Pension And Employee Benefit Expense      8.200000e+07
# Gain Loss On Sale Of Business             0.000000e+00
# Net Income From Continuing Operations     7.280000e+08
# Name: 2024-12-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items               6.551300e+07
# Tax Rate For Calcs                        1.910000e-01
# Normalized EBITDA                         1.587000e+09
# Total Unusual Items                       3.430000e+08
# Total Unusual Items Excluding Goodwill    3.430000e+08
#                                               ...
# Depreciation And Amortization             2.900000e+08
# Operating Gains Losses                    6.900000e+07
# Pension And Employee Benefit Expense      6.900000e+07
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations     1.122000e+09
# Name: 2025-03-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items              -2.660000e+06
# Tax Rate For Calcs                        2.660000e-01
# Normalized EBITDA                         1.460000e+09
# Total Unusual Items                      -1.000000e+07
# Total Unusual Items Excluding Goodwill   -1.000000e+07
#                                               ...
# Depreciation And Amortization             2.900000e+08
# Operating Gains Losses                    6.900000e+07
# Pension And Employee Benefit Expense      6.600000e+07
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations     7.250000e+08
# Name: 2025-06-30 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items                     NaN
# Tax Rate For Calcs                              NaN
# Normalized EBITDA                               NaN
# Total Unusual Items                      -3200000.0
# Total Unusual Items Excluding Goodwill   -3200000.0
#                                             ...
# Depreciation Amortization Depletion             NaN
# Depreciation And Amortization                   NaN
# Operating Gains Losses                    3600000.0
# Pension And Employee Benefit Expense      3600000.0
# Net Income From Continuing Operations           NaN
# Name: 2023-12-31 00:00:00, Length: 146, dtype: float64
# Tax Effect Of Unusual Items               NaN
# Tax Rate For Calcs                        NaN
# Normalized EBITDA                         NaN
# Total Unusual Items                       0.0
# Total Unusual Items Excluding Goodwill    0.0
#                                          ...
# Depreciation Amortization Depletion       NaN
# Depreciation And Amortization             NaN
# Operating Gains Losses                    NaN
# Pension And Employee Benefit Expense      NaN
# Net Income From Continuing Operations     NaN
# Name: 2024-03-31 00:00:00, Length: 146, dtype: float64
# Tax Effect Of Unusual Items               0.000000e+00
# Tax Rate For Calcs                        2.439500e-01
# Normalized EBITDA                         2.280000e+08
# Total Unusual Items                       0.000000e+00
# Total Unusual Items Excluding Goodwill    0.000000e+00
#                                               ...
# Depreciation Amortization Depletion       1.960000e+07
# Depreciation And Amortization             1.960000e+07
# Operating Gains Losses                             NaN
# Pension And Employee Benefit Expense               NaN
# Net Income From Continuing Operations     1.562000e+08
# Name: 2024-06-30 00:00:00, Length: 146, dtype: float64
# Tax Effect Of Unusual Items               0.000000e+00
# Tax Rate For Calcs                        2.330000e-01
# Normalized EBITDA                         1.784000e+08
# Total Unusual Items                       0.000000e+00
# Total Unusual Items Excluding Goodwill    0.000000e+00
#                                               ...
# Depreciation Amortization Depletion       2.030000e+07
# Depreciation And Amortization             2.030000e+07
# Operating Gains Losses                             NaN
# Pension And Employee Benefit Expense      0.000000e+00
# Net Income From Continuing Operations     1.201000e+08
# Name: 2024-09-30 00:00:00, Length: 146, dtype: float64
# Tax Effect Of Unusual Items              -4.293866e+06
# Tax Rate For Calcs                        2.439700e-01
# Normalized EBITDA                         1.844000e+08
# Total Unusual Items                      -1.760000e+07
# Total Unusual Items Excluding Goodwill   -1.760000e+07
#                                               ...
# Depreciation Amortization Depletion       1.930000e+07
# Depreciation And Amortization             1.930000e+07
# Operating Gains Losses                             NaN
# Pension And Employee Benefit Expense      0.000000e+00
# Net Income From Continuing Operations     1.097000e+08
# Name: 2024-12-31 00:00:00, Length: 146, dtype: float64
# Tax Effect Of Unusual Items               0.000000e+00
# Tax Rate For Calcs                        2.460000e-01
# Normalized EBITDA                         2.047000e+08
# Total Unusual Items                                NaN
# Total Unusual Items Excluding Goodwill             NaN
#                                               ...
# Depreciation Amortization Depletion       2.070000e+07
# Depreciation And Amortization             2.070000e+07
# Operating Gains Losses                             NaN
# Pension And Employee Benefit Expense               NaN
# Net Income From Continuing Operations     1.366000e+08
# Name: 2025-03-31 00:00:00, Length: 146, dtype: float64
# Tax Effect Of Unusual Items               0.000000e+00
# Tax Rate For Calcs                        2.450400e-01
# Normalized EBITDA                         2.267000e+08
# Total Unusual Items                                NaN
# Total Unusual Items Excluding Goodwill             NaN
#                                               ...
# Depreciation Amortization Depletion       2.050000e+07
# Depreciation And Amortization             2.050000e+07
# Operating Gains Losses                             NaN
# Pension And Employee Benefit Expense               NaN
# Net Income From Continuing Operations     1.522000e+08
# Name: 2025-06-30 00:00:00, Length: 146, dtype: float64
# Tax Effect Of Unusual Items              NaN
# Tax Rate For Calcs                       NaN
# Normalized EBITDA                        NaN
# Total Unusual Items                      NaN
# Total Unusual Items Excluding Goodwill   NaN
#                                           ..
# Depreciation And Amortization            NaN
# Amortization Cash Flow                   NaN
# Amortization Of Intangibles              NaN
# Depreciation                             NaN
# Net Income From Continuing Operations    NaN
# Name: 2023-12-31 00:00:00, Length: 164, dtype: float64
# Tax Effect Of Unusual Items              NaN
# Tax Rate For Calcs                       NaN
# Normalized EBITDA                        NaN
# Total Unusual Items                      NaN
# Total Unusual Items Excluding Goodwill   NaN
#                                           ..
# Depreciation And Amortization            NaN
# Amortization Cash Flow                   NaN
# Amortization Of Intangibles              NaN
# Depreciation                             NaN
# Net Income From Continuing Operations    NaN
# Name: 2024-03-31 00:00:00, Length: 164, dtype: float64
# Tax Effect Of Unusual Items               1.138768e+06
# Tax Rate For Calcs                        1.897950e-01
# Normalized EBITDA                         2.546000e+09
# Total Unusual Items                       6.000000e+06
# Total Unusual Items Excluding Goodwill    6.000000e+06
#                                               ...
# Depreciation And Amortization             8.050000e+08
# Amortization Cash Flow                    4.710000e+08
# Amortization Of Intangibles               4.710000e+08
# Depreciation                              3.340000e+08
# Net Income From Continuing Operations     1.302000e+09
# Name: 2024-06-30 00:00:00, Length: 164, dtype: float64
# Tax Effect Of Unusual Items               1.667010e+06
# Tax Rate For Calcs                        1.515460e-01
# Normalized EBITDA                         2.872000e+09
# Total Unusual Items                       1.100000e+07
# Total Unusual Items Excluding Goodwill    1.100000e+07
#                                               ...
# Depreciation And Amortization             8.010000e+08
# Amortization Cash Flow                    4.700000e+08
# Amortization Of Intangibles               4.700000e+08
# Depreciation                              3.310000e+08
# Net Income From Continuing Operations     1.646000e+09
# Name: 2024-09-30 00:00:00, Length: 164, dtype: float64
# Tax Effect Of Unusual Items               2.100000e+06
# Tax Rate For Calcs                        2.100000e-01
# Normalized EBITDA                         2.963000e+09
# Total Unusual Items                       1.000000e+07
# Total Unusual Items Excluding Goodwill    1.000000e+07
#                                               ...
# Depreciation And Amortization             8.070000e+08
# Amortization Cash Flow                    4.650000e+08
# Amortization Of Intangibles               4.650000e+08
# Depreciation                              3.420000e+08
# Net Income From Continuing Operations     9.229000e+09
# Name: 2024-12-31 00:00:00, Length: 164, dtype: float64
# Tax Effect Of Unusual Items               1.783465e+06
# Tax Rate For Calcs                        2.547810e-01
# Normalized EBITDA                         2.658000e+09
# Total Unusual Items                       7.000000e+06
# Total Unusual Items Excluding Goodwill    7.000000e+06
#                                               ...
# Depreciation And Amortization             7.560000e+08
# Amortization Cash Flow                    4.200000e+08
# Amortization Of Intangibles               4.200000e+08
# Depreciation                              3.360000e+08
# Net Income From Continuing Operations     1.325000e+09
# Name: 2025-03-31 00:00:00, Length: 164, dtype: float64
# Tax Effect Of Unusual Items               1.898140e+06
# Tax Rate For Calcs                        1.725580e-01
# Normalized EBITDA                         3.037000e+09
# Total Unusual Items                       1.100000e+07
# Total Unusual Items Excluding Goodwill    1.100000e+07
#                                               ...
# Depreciation And Amortization             7.770000e+08
# Amortization Cash Flow                    4.200000e+08
# Amortization Of Intangibles               4.200000e+08
# Depreciation                              3.570000e+08
# Net Income From Continuing Operations     1.779000e+09
# Name: 2025-06-30 00:00:00, Length: 164, dtype: float64
# Tax Effect Of Unusual Items               NaN
# Tax Rate For Calcs                        NaN
# Normalized EBITDA                         NaN
# Total Unusual Items                       NaN
# Total Unusual Items Excluding Goodwill    NaN
#                                          ...
# Amortization Cash Flow                    NaN
# Amortization Of Intangibles               NaN
# Depreciation                              NaN
# Gain Loss On Sale Of Business             0.0
# Net Income From Continuing Operations     NaN
# Name: 2023-12-31 00:00:00, Length: 172, dtype: float64
# Tax Effect Of Unusual Items              NaN
# Tax Rate For Calcs                       NaN
# Normalized EBITDA                        NaN
# Total Unusual Items                      NaN
# Total Unusual Items Excluding Goodwill   NaN
#                                           ..
# Amortization Cash Flow                   NaN
# Amortization Of Intangibles              NaN
# Depreciation                             NaN
# Gain Loss On Sale Of Business            NaN
# Net Income From Continuing Operations    NaN
# Name: 2024-03-31 00:00:00, Length: 172, dtype: float64
# Tax Effect Of Unusual Items              -3.378723e+08
# Tax Rate For Calcs                        3.602050e-01
# Normalized EBITDA                         5.941000e+09
# Total Unusual Items                      -9.380000e+08
# Total Unusual Items Excluding Goodwill   -9.380000e+08
#                                               ...
# Amortization Cash Flow                    1.947000e+09
# Amortization Of Intangibles               1.947000e+09
# Depreciation                              1.840000e+08
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations     1.373000e+09
# Name: 2024-06-30 00:00:00, Length: 172, dtype: float64
# Tax Effect Of Unusual Items              -1.975000e+07
# Tax Rate For Calcs                        2.500000e-01
# Normalized EBITDA                         4.962000e+09
# Total Unusual Items                      -7.900000e+07
# Total Unusual Items Excluding Goodwill   -7.900000e+07
#                                               ...
# Amortization Cash Flow                    1.888000e+09
# Amortization Of Intangibles               1.888000e+09
# Depreciation                              1.910000e+08
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations     1.564000e+09
# Name: 2024-09-30 00:00:00, Length: 172, dtype: float64
# Tax Effect Of Unusual Items              -3.345300e+08
# Tax Rate For Calcs                        2.100000e-01
# Normalized EBITDA                         2.128000e+09
# Total Unusual Items                      -1.593000e+09
# Total Unusual Items Excluding Goodwill   -1.593000e+09
#                                               ...
# Amortization Cash Flow                    1.896000e+09
# Amortization Of Intangibles               1.896000e+09
# Depreciation                              2.060000e+08
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations    -2.300000e+07
# Name: 2024-12-31 00:00:00, Length: 172, dtype: float64
# Tax Effect Of Unusual Items              -5.544000e+07
# Tax Rate For Calcs                        2.200000e-01
# Normalized EBITDA                         4.652000e+09
# Total Unusual Items                      -2.520000e+08
# Total Unusual Items Excluding Goodwill   -2.520000e+08
#                                               ...
# Amortization Cash Flow                    1.858000e+09
# Amortization Of Intangibles               1.858000e+09
# Depreciation                              1.810000e+08
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations     1.289000e+09
# Name: 2025-03-31 00:00:00, Length: 172, dtype: float64
# Tax Effect Of Unusual Items              -3.337181e+08
# Tax Rate For Calcs                        3.944660e-01
# Normalized EBITDA                         5.190000e+09
# Total Unusual Items                      -8.460000e+08
# Total Unusual Items Excluding Goodwill   -8.460000e+08
#                                               ...
# Amortization Cash Flow                    1.864000e+09
# Amortization Of Intangibles               1.864000e+09
# Depreciation                              1.860000e+08
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations     9.410000e+08
# Name: 2025-06-30 00:00:00, Length: 172, dtype: float64
# Tax Effect Of Unusual Items                                  NaN
# Tax Rate For Calcs                                           NaN
# Normalized EBITDA                                            NaN
# Net Income From Continuing Operation Net Minority Interest   NaN
# Reconciled Depreciation                                      NaN
#                                                               ..
# Depreciation And Amortization                                NaN
# Amortization Cash Flow                                       NaN
# Amortization Of Intangibles                                  NaN
# Depreciation                                                 NaN
# Net Income From Continuing Operations                        NaN
# Name: 2023-11-30 00:00:00, Length: 175, dtype: float64
# Tax Effect Of Unusual Items                                  NaN
# Tax Rate For Calcs                                           NaN
# Normalized EBITDA                                            NaN
# Net Income From Continuing Operation Net Minority Interest   NaN
# Reconciled Depreciation                                      NaN
#                                                               ..
# Depreciation And Amortization                                NaN
# Amortization Cash Flow                                       NaN
# Amortization Of Intangibles                                  NaN
# Depreciation                                                 NaN
# Net Income From Continuing Operations                        NaN
# Name: 2024-02-29 00:00:00, Length: 175, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.540000e-01
# Normalized EBITDA                                             2.936933e+09
# Net Income From Continuing Operation Net Minority Interest    1.932183e+09
# Reconciled Depreciation                                       2.712290e+08
#                                                                   ...
# Depreciation And Amortization                                 2.712290e+08
# Amortization Cash Flow                                        1.330970e+08
# Amortization Of Intangibles                                   1.330970e+08
# Depreciation                                                  1.381320e+08
# Net Income From Continuing Operations                         1.981348e+09
# Name: 2024-05-31 00:00:00, Length: 175, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.631850e-01
# Normalized EBITDA                                             2.662666e+09
# Net Income From Continuing Operation Net Minority Interest    1.684301e+09
# Reconciled Depreciation                                       3.072700e+08
#                                                                   ...
# Depreciation And Amortization                                 3.072700e+08
# Amortization Cash Flow                                        1.657090e+08
# Amortization Of Intangibles                                   1.657090e+08
# Depreciation                                                  1.415610e+08
# Net Income From Continuing Operations                         1.718666e+09
# Name: 2024-08-31 00:00:00, Length: 175, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.160000e-01
# Normalized EBITDA                                             3.203710e+09
# Net Income From Continuing Operation Net Minority Interest    2.278894e+09
# Reconciled Depreciation                                       2.184230e+08
#                                                                   ...
# Depreciation And Amortization                                 2.184230e+08
# Amortization Cash Flow                                        8.532400e+07
# Amortization Of Intangibles                                   8.532400e+07
# Depreciation                                                  1.330990e+08
# Net Income From Continuing Operations                         2.316190e+09
# Name: 2024-11-30 00:00:00, Length: 175, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.040000e-01
# Normalized EBITDA                                             2.714304e+09
# Net Income From Continuing Operation Net Minority Interest    1.788075e+09
# Reconciled Depreciation                                       3.608610e+08
#                                                                   ...
# Depreciation And Amortization                                 3.608610e+08
# Amortization Cash Flow                                        2.270520e+08
# Amortization Of Intangibles                                   2.270520e+08
# Depreciation                                                  1.338090e+08
# Net Income From Continuing Operations                         1.822441e+09
# Name: 2025-02-28 00:00:00, Length: 175, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.400000e-01
# Normalized EBITDA                                             3.310745e+09
# Net Income From Continuing Operation Net Minority Interest    2.197501e+09
# Reconciled Depreciation                                       2.920050e+08
#                                                                   ...
# Depreciation And Amortization                                 2.920050e+08
# Amortization Cash Flow                                        1.531990e+08
# Amortization Of Intangibles                                   1.531990e+08
# Depreciation                                                  1.388060e+08
# Net Income From Continuing Operations                         2.243963e+09
# Name: 2025-05-31 00:00:00, Length: 175, dtype: float64
# Tax Effect Of Unusual Items                      NaN
# Tax Rate For Calcs                               NaN
# Normalized EBITDA                                NaN
# Total Unusual Items                              NaN
# Total Unusual Items Excluding Goodwill           NaN
#                                              ...
# Depreciation And Amortization                    NaN
# Depreciation                                     NaN
# Operating Gains Losses                    18000000.0
# Gain Loss On Sale Of PPE                  18000000.0
# Net Income From Continuing Operations            NaN
# Name: 2023-11-30 00:00:00, Length: 181, dtype: float64
# Tax Effect Of Unusual Items                      NaN
# Tax Rate For Calcs                               NaN
# Normalized EBITDA                                NaN
# Total Unusual Items                              NaN
# Total Unusual Items Excluding Goodwill           NaN
#                                              ...
# Depreciation And Amortization                    NaN
# Depreciation                                     NaN
# Operating Gains Losses                    18000000.0
# Gain Loss On Sale Of PPE                  18000000.0
# Net Income From Continuing Operations            NaN
# Name: 2024-02-29 00:00:00, Length: 181, dtype: float64
# Tax Effect Of Unusual Items               7.200000e+05
# Tax Rate For Calcs                        1.800000e-01
# Normalized EBITDA                         2.181000e+09
# Total Unusual Items                       4.000000e+06
# Total Unusual Items Excluding Goodwill    4.000000e+06
#                                               ...
# Depreciation And Amortization             2.140000e+08
# Depreciation                              2.140000e+08
# Operating Gains Losses                    1.900000e+07
# Gain Loss On Sale Of PPE                  1.900000e+07
# Net Income From Continuing Operations     1.573000e+09
# Name: 2024-05-31 00:00:00, Length: 181, dtype: float64
# Tax Effect Of Unusual Items               2.160000e+06
# Tax Rate For Calcs                        1.800000e-01
# Normalized EBITDA                         2.294000e+09
# Total Unusual Items                       1.200000e+07
# Total Unusual Items Excluding Goodwill    1.200000e+07
#                                               ...
# Depreciation And Amortization             2.130000e+08
# Depreciation                              2.130000e+08
# Operating Gains Losses                    1.900000e+07
# Gain Loss On Sale Of PPE                  1.900000e+07
# Net Income From Continuing Operations     1.684000e+09
# Name: 2024-08-31 00:00:00, Length: 181, dtype: float64
# Tax Effect Of Unusual Items              -2.475138e+06
# Tax Rate For Calcs                        1.546960e-01
# Normalized EBITDA                         2.275000e+09
# Total Unusual Items                      -1.600000e+07
# Total Unusual Items Excluding Goodwill   -1.600000e+07
#                                               ...
# Depreciation And Amortization             2.180000e+08
# Depreciation                              2.180000e+08
# Operating Gains Losses                    2.100000e+07
# Gain Loss On Sale Of PPE                  2.100000e+07
# Net Income From Continuing Operations     1.683000e+09
# Name: 2024-11-30 00:00:00, Length: 181, dtype: float64
# Tax Effect Of Unusual Items               1.020000e+06
# Tax Rate For Calcs                        1.700000e-01
# Normalized EBITDA                         2.455000e+09
# Total Unusual Items                       6.000000e+06
# Total Unusual Items Excluding Goodwill    6.000000e+06
#                                               ...
# Depreciation And Amortization             2.170000e+08
# Depreciation                              2.170000e+08
# Operating Gains Losses                             NaN
# Gain Loss On Sale Of PPE                           NaN
# Net Income From Continuing Operations     1.811000e+09
# Name: 2025-02-28 00:00:00, Length: 181, dtype: float64
# Tax Effect Of Unusual Items               4.000000e+05
# Tax Rate For Calcs                        2.000000e-01
# Normalized EBITDA                         2.376000e+09
# Total Unusual Items                       2.000000e+06
# Total Unusual Items Excluding Goodwill    2.000000e+06
#                                               ...
# Depreciation And Amortization             2.090000e+08
# Depreciation                              2.090000e+08
# Operating Gains Losses                             NaN
# Gain Loss On Sale Of PPE                           NaN
# Net Income From Continuing Operations     1.691000e+09
# Name: 2025-05-31 00:00:00, Length: 181, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.100000e-01
# Normalized EBITDA                                             7.210000e+08
# Net Income From Continuing Operation Net Minority Interest    7.680000e+08
# Reconciled Depreciation                                       7.570000e+08
#                                                                   ...
# Amortization Of Intangibles                                   5.680000e+08
# Depreciation                                                  1.890000e+08
# Operating Gains Losses                                                 NaN
# Gain Loss On Sale Of PPE                                               NaN
# Net Income From Continuing Operations                         7.680000e+08
# Name: 2025-06-30 00:00:00, Length: 171, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.480000e-01
# Normalized EBITDA                                             1.587000e+09
# Net Income From Continuing Operation Net Minority Interest    7.090000e+08
# Reconciled Depreciation                                       7.420000e+08
#                                                                   ...
# Amortization Of Intangibles                                   5.670000e+08
# Depreciation                                                  1.750000e+08
# Operating Gains Losses                                                 NaN
# Gain Loss On Sale Of PPE                                               NaN
# Net Income From Continuing Operations                         7.090000e+08
# Name: 2025-03-31 00:00:00, Length: 171, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.100000e-01
# Normalized EBITDA                                             1.694000e+09
# Net Income From Continuing Operation Net Minority Interest    4.820000e+08
# Reconciled Depreciation                                       7.860000e+08
#                                                                   ...
# Amortization Of Intangibles                                            NaN
# Depreciation                                                 -1.607000e+09
# Operating Gains Losses                                                 NaN
# Gain Loss On Sale Of PPE                                               NaN
# Net Income From Continuing Operations                         4.820000e+08
# Name: 2024-12-31 00:00:00, Length: 171, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.100000e-01
# Normalized EBITDA                                             1.598000e+09
# Net Income From Continuing Operation Net Minority Interest    7.710000e+08
# Reconciled Depreciation                                       8.380000e+08
#                                                                   ...
# Amortization Of Intangibles                                            NaN
# Depreciation                                                  2.063000e+09
# Operating Gains Losses                                                 NaN
# Gain Loss On Sale Of PPE                                               NaN
# Net Income From Continuing Operations                         7.710000e+08
# Name: 2024-09-30 00:00:00, Length: 171, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.371240e-01
# Normalized EBITDA                                             1.093000e+09
# Net Income From Continuing Operation Net Minority Interest    2.650000e+08
# Reconciled Depreciation                                       7.690000e+08
#                                                                   ...
# Amortization Of Intangibles                                   6.030000e+08
# Depreciation                                                  1.660000e+08
# Operating Gains Losses                                                 NaN
# Gain Loss On Sale Of PPE                                               NaN
# Net Income From Continuing Operations                         2.650000e+08
# Name: 2024-06-30 00:00:00, Length: 171, dtype: float64
# Tax Effect Of Unusual Items                                           NaN
# Tax Rate For Calcs                                                    NaN
# Normalized EBITDA                                                     NaN
# Net Income From Continuing Operation Net Minority Interest            NaN
# Reconciled Depreciation                                               NaN
#                                                                  ...
# Amortization Of Intangibles                                   622000000.0
# Depreciation                                                          NaN
# Operating Gains Losses                                                NaN
# Gain Loss On Sale Of PPE                                              NaN
# Net Income From Continuing Operations                                 NaN
# Name: 2024-03-31 00:00:00, Length: 171, dtype: float64
# Tax Effect Of Unusual Items                                         NaN
# Tax Rate For Calcs                                                  NaN
# Normalized EBITDA                                                   NaN
# Net Income From Continuing Operation Net Minority Interest          NaN
# Reconciled Depreciation                                             NaN
#                                                                 ...
# Amortization Of Intangibles                                         NaN
# Depreciation                                                        NaN
# Operating Gains Losses                                        1000000.0
# Gain Loss On Sale Of PPE                                      1000000.0
# Net Income From Continuing Operations                               NaN
# Name: 2023-12-31 00:00:00, Length: 171, dtype: float64
# Tax Effect Of Unusual Items                3.402000e+07
# Tax Rate For Calcs                         2.100000e-01
# Normalized EBITDA                          5.830000e+08
# Total Unusual Items                        1.620000e+08
# Total Unusual Items Excluding Goodwill     1.620000e+08
#                                                ...
# Operating Gains Losses                     4.000000e+07
# Gain Loss On Investment Securities         8.600000e+07
# Net Foreign Currency Exchange Gain Loss             NaN
# Gain Loss On Sale Of Business             -7.000000e+07
# Net Income From Continuing Operations     -1.500000e+08
# Name: 2025-06-30 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items               -2.268000e+07
# Tax Rate For Calcs                         2.100000e-01
# Normalized EBITDA                          7.650000e+08
# Total Unusual Items                       -1.080000e+08
# Total Unusual Items Excluding Goodwill    -1.080000e+08
#                                                ...
# Operating Gains Losses                    -1.400000e+07
# Gain Loss On Investment Securities        -1.500000e+07
# Net Foreign Currency Exchange Gain Loss             NaN
# Gain Loss On Sale Of Business              1.000000e+06
# Net Income From Continuing Operations     -7.300000e+07
# Name: 2025-03-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items                6.961644e+06
# Tax Rate For Calcs                         1.917800e-02
# Normalized EBITDA                          7.000000e+08
# Total Unusual Items                        3.630000e+08
# Total Unusual Items Excluding Goodwill     3.630000e+08
#                                                ...
# Operating Gains Losses                    -2.410000e+08
# Gain Loss On Investment Securities         5.100000e+07
# Net Foreign Currency Exchange Gain Loss    1.600000e+07
# Gain Loss On Sale Of Business             -3.080000e+08
# Net Income From Continuing Operations      3.530000e+08
# Name: 2024-12-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items               -3.689000e+07
# Tax Rate For Calcs                         3.100000e-01
# Normalized EBITDA                          1.133000e+09
# Total Unusual Items                       -1.190000e+08
# Total Unusual Items Excluding Goodwill    -1.190000e+08
#                                                ...
# Operating Gains Losses                    -4.200000e+07
# Gain Loss On Investment Securities        -5.700000e+07
# Net Foreign Currency Exchange Gain Loss    1.400000e+07
# Gain Loss On Sale Of Business              1.000000e+06
# Net Income From Continuing Operations      2.100000e+08
# Name: 2024-09-30 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items               -4.221000e+07
# Tax Rate For Calcs                         2.100000e-01
# Normalized EBITDA                          8.150000e+08
# Total Unusual Items                       -2.010000e+08
# Total Unusual Items Excluding Goodwill    -2.010000e+08
#                                                ...
# Operating Gains Losses                     1.300000e+07
# Gain Loss On Investment Securities        -6.400000e+07
# Net Foreign Currency Exchange Gain Loss             NaN
# Gain Loss On Sale Of Business             -1.000000e+06
# Net Income From Continuing Operations     -3.900000e+07
# Name: 2024-06-30 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items               NaN
# Tax Rate For Calcs                        NaN
# Normalized EBITDA                         NaN
# Total Unusual Items                       NaN
# Total Unusual Items Excluding Goodwill    NaN
#                                            ..
# Operating Gains Losses                    NaN
# Gain Loss On Investment Securities        NaN
# Net Foreign Currency Exchange Gain Loss   NaN
# Gain Loss On Sale Of Business             NaN
# Net Income From Continuing Operations     NaN
# Name: 2024-03-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items                        NaN
# Tax Rate For Calcs                                 NaN
# Normalized EBITDA                                  NaN
# Total Unusual Items                                NaN
# Total Unusual Items Excluding Goodwill             NaN
#                                               ...
# Operating Gains Losses                             NaN
# Gain Loss On Investment Securities                 NaN
# Net Foreign Currency Exchange Gain Loss    147000000.0
# Gain Loss On Sale Of Business                      NaN
# Net Income From Continuing Operations              NaN
# Name: 2023-12-31 00:00:00, Length: 194, dtype: float64
# Tax Effect Of Unusual Items                                  NaN
# Tax Rate For Calcs                                           NaN
# Net Income From Continuing Operation Net Minority Interest   NaN
# EBIT                                                         NaN
# Net Interest Income                                          NaN
#                                                               ..
# Amortization Of Securities                                   NaN
# Operating Gains Losses                                       NaN
# Gain Loss On Investment Securities                           NaN
# Net Foreign Currency Exchange Gain Loss                      NaN
# Net Income From Continuing Operations                        NaN
# Name: 2023-12-31 00:00:00, Length: 116, dtype: float64
# Tax Effect Of Unusual Items                                  NaN
# Tax Rate For Calcs                                           NaN
# Net Income From Continuing Operation Net Minority Interest   NaN
# EBIT                                                         NaN
# Net Interest Income                                          NaN
#                                                               ..
# Amortization Of Securities                                   NaN
# Operating Gains Losses                                       NaN
# Gain Loss On Investment Securities                           NaN
# Net Foreign Currency Exchange Gain Loss                      NaN
# Net Income From Continuing Operations                        NaN
# Name: 2024-03-31 00:00:00, Length: 116, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.307580e-01
# Net Income From Continuing Operation Net Minority Interest    1.755000e+09
# EBIT                                                          2.069000e+09
# Net Interest Income                                          -5.000000e+07
#                                                                   ...
# Amortization Of Securities                                   -4.500000e+07
# Operating Gains Losses                                       -9.900000e+08
# Gain Loss On Investment Securities                            5.000000e+06
# Net Foreign Currency Exchange Gain Loss                      -9.950000e+08
# Net Income From Continuing Operations                         1.755000e+09
# Name: 2024-06-30 00:00:00, Length: 116, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.100000e-01
# Net Income From Continuing Operation Net Minority Interest   -9.300000e+07
# EBIT                                                          1.420000e+08
# Net Interest Income                                          -5.000000e+07
#                                                                   ...
# Amortization Of Securities                                   -4.500000e+07
# Operating Gains Losses                                        1.758000e+09
# Gain Loss On Investment Securities                            1.100000e+08
# Net Foreign Currency Exchange Gain Loss                       1.648000e+09
# Net Income From Continuing Operations                        -9.300000e+07
# Name: 2024-09-30 00:00:00, Length: 116, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.091330e-01
# Net Income From Continuing Operation Net Minority Interest    1.902000e+09
# EBIT                                                          2.185000e+09
# Net Interest Income                                          -5.000000e+07
#                                                                   ...
# Amortization Of Securities                                   -7.600000e+07
# Operating Gains Losses                                       -1.436000e+09
# Gain Loss On Investment Securities                            1.800000e+08
# Net Foreign Currency Exchange Gain Loss                      -1.616000e+09
# Net Income From Continuing Operations                         1.902000e+09
# Name: 2024-12-31 00:00:00, Length: 116, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.100000e-01
# Net Income From Continuing Operation Net Minority Interest    2.900000e+07
# EBIT                                                          1.950000e+08
# Net Interest Income                                          -5.000000e+07
#                                                                   ...
# Amortization Of Securities                                   -3.000000e+07
# Operating Gains Losses                                        8.630000e+08
# Gain Loss On Investment Securities                            1.810000e+08
# Net Foreign Currency Exchange Gain Loss                       6.820000e+08
# Net Income From Continuing Operations                         2.900000e+07
# Name: 2025-03-31 00:00:00, Length: 116, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            2.712900e-01
# Net Income From Continuing Operation Net Minority Interest    5.990000e+08
# EBIT                                                          8.740000e+08
# Net Interest Income                                          -5.200000e+07
#                                                                   ...
# Amortization Of Securities                                   -3.600000e+07
# Operating Gains Losses                                        3.800000e+08
# Gain Loss On Investment Securities                           -1.600000e+07
# Net Foreign Currency Exchange Gain Loss                       3.960000e+08
# Net Income From Continuing Operations                         5.990000e+08
# Name: 2025-06-30 00:00:00, Length: 116, dtype: float64
# Tax Effect Of Unusual Items                                  NaN
# Tax Rate For Calcs                                           NaN
# Normalized EBITDA                                            NaN
# Net Income From Continuing Operation Net Minority Interest   NaN
# Reconciled Depreciation                                      NaN
#                                                               ..
# Depreciation Amortization Depletion                          NaN
# Depreciation And Amortization                                NaN
# Operating Gains Losses                                       NaN
# Gain Loss On Investment Securities                           NaN
# Net Income From Continuing Operations                        NaN
# Name: 2024-01-31 00:00:00, Length: 157, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.760000e-01
# Normalized EBITDA                                             4.570000e+08
# Net Income From Continuing Operation Net Minority Interest    3.080000e+08
# Reconciled Depreciation                                       6.300000e+07
#                                                                   ...
# Depreciation Amortization Depletion                           6.300000e+07
# Depreciation And Amortization                                 6.300000e+07
# Operating Gains Losses                                       -1.000000e+06
# Gain Loss On Investment Securities                           -1.000000e+06
# Net Income From Continuing Operations                         3.080000e+08
# Name: 2024-04-30 00:00:00, Length: 157, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.780000e-01
# Normalized EBITDA                                             4.280000e+08
# Net Income From Continuing Operation Net Minority Interest    2.820000e+08
# Reconciled Depreciation                                       6.300000e+07
#                                                                   ...
# Depreciation Amortization Depletion                           6.300000e+07
# Depreciation And Amortization                                 6.300000e+07
# Operating Gains Losses                                       -2.000000e+06
# Gain Loss On Investment Securities                           -2.000000e+06
# Net Income From Continuing Operations                         2.820000e+08
# Name: 2024-07-31 00:00:00, Length: 157, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.246880e-01
# Normalized EBITDA                                             5.020000e+08
# Net Income From Continuing Operation Net Minority Interest    3.510000e+08
# Reconciled Depreciation                                       6.900000e+07
#                                                                   ...
# Depreciation Amortization Depletion                           6.900000e+07
# Depreciation And Amortization                                 6.900000e+07
# Operating Gains Losses                                        0.000000e+00
# Gain Loss On Investment Securities                            0.000000e+00
# Net Income From Continuing Operations                         3.510000e+08
# Name: 2024-10-31 00:00:00, Length: 157, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.340000e-01
# Normalized EBITDA                                             4.670000e+08
# Net Income From Continuing Operation Net Minority Interest    3.180000e+08
# Reconciled Depreciation                                       7.200000e+07
#                                                                   ...
# Depreciation Amortization Depletion                           7.200000e+07
# Depreciation And Amortization                                 7.200000e+07
# Operating Gains Losses                                       -1.000000e+06
# Gain Loss On Investment Securities                           -1.000000e+06
# Net Income From Continuing Operations                         3.180000e+08
# Name: 2025-01-31 00:00:00, Length: 157, dtype: float64
# Tax Effect Of Unusual Items                                   0.000000e+00
# Tax Rate For Calcs                                            1.730770e-01
# Normalized EBITDA                                             3.620000e+08
# Net Income From Continuing Operation Net Minority Interest    2.150000e+08
# Reconciled Depreciation                                       7.300000e+07
#                                                                   ...
# Depreciation Amortization Depletion                           7.300000e+07
# Depreciation And Amortization                                 7.300000e+07
# Operating Gains Losses                                        2.800000e+07
# Gain Loss On Investment Securities                            2.800000e+07
# Net Income From Continuing Operations                         2.150000e+08
# Name: 2025-04-30 00:00:00, Length: 157, dtype: float64

# %%
type(all_feats)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, classification_report

# Features & target
X = all_feats.drop(columns=["date", "ticker", "target"]).fillna(0)
y = all_feats["target"]

# Build pipeline: scaling -> PCA -> classifier
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("pca", PCA(n_components=0.95)),  # keep enough components to explain 95% variance
    ("clf", RandomForestClassifier(n_estimators=200, random_state=42))
])

# K-fold CV
kf = KFold(n_splits=5, shuffle=True, random_state=42)
scores = []

for train_idx, test_idx in kf.split(X):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    pipeline.fit(X_train, y_train)
    preds = pipeline.predict(X_test)
    acc = accuracy_score(y_test, preds)
    scores.append(acc)

print("Cross-validated Accuracy:", np.mean(scores))

# %%
import joblib
import yfinance as yf
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report

def safe_div(df, num, den):
    if num in df.columns and den in df.columns:
        return df[num] / df[den]
    else:
        return pd.Series([np.nan] * len(df), index=df.index)
    
def get_fundamentals(ticker, get_train, lookahead_days=90):
    t = yf.Ticker(ticker)
    inc = t.quarterly_financials.T
    bal = t.quarterly_balance_sheet.T
    cf  = t.quarterly_cashflow.T

    df_raw = pd.concat([inc, bal, cf], axis=1)

    # Profitability Ratios
    df_extract = pd.DataFrame()

    # Profitability Ratios
    df_extract['Gross_Margin']      = safe_div(df_raw, 'Gross Profit', 'Total Revenue')
    df_extract['Operating_Margin']  = safe_div(df_raw, 'Operating Income', 'Total Revenue')
    df_extract['Net_Margin']        = safe_div(df_raw, 'Net Income', 'Total Revenue')
    df_extract['EBITDA_Margin']     = safe_div(df_raw, 'EBITDA', 'Total Revenue')

    # Growth Ratios (YoY)
    df_extract['Revenue_Growth']    = df_raw['Total Revenue'].pct_change(fill_method=None) if 'Total Revenue' in df_raw else np.nan
    df_extract['Net_Income_Growth'] = df_raw['Net Income'].pct_change(fill_method=None) if 'Net Income' in df_raw else np.nan
    df_extract['EPS_Growth']        = df_raw['Diluted EPS'].pct_change(fill_method=None) if 'Diluted EPS' in df_raw else np.nan

    # Return Ratios
    df_extract['ROE']   = safe_div(df_raw, 'Net Income', 'Stockholders Equity')
    df_extract['ROA']   = safe_div(df_raw, 'Net Income', 'Total Assets')
    df_extract['ROIC']  = safe_div(df_raw, 'EBIT', 'Total Debt') + safe_div(df_raw, 'EBIT', 'Stockholders Equity') - safe_div(df_raw, 'EBIT', 'Cash And Cash Equivalents')

    # Leverage Ratios
    df_extract['Debt_to_Equity']      = safe_div(df_raw, 'Total Debt', 'Stockholders Equity')
    df_extract['Net_Debt_to_EBITDA']  = safe_div(df_raw, 'Net Debt', 'EBITDA')

    # Liquidity Ratios
    df_extract['Current_Ratio'] = safe_div(df_raw, 'Current Assets', 'Current Liabilities')
    df_extract['Quick_Ratio']   = safe_div(df_raw, 'Current Assets', 'Current Liabilities') - safe_div(df_raw, 'Inventory', 'Current Liabilities')

    # Cash Flow Metrics
    df_extract['FCF_to_Sales']  = safe_div(df_raw, 'Free Cash Flow', 'Total Revenue')
    df_extract['FCF_yield']     = safe_div(df_raw, 'Free Cash Flow', 'Stockholders Equity')

    df_extract['Report_Date'] = df_extract.index

    for col in df_extract.columns:
        if df_extract[col].isna().all():
            df_extract[col] = df_extract[col].fillna(0)
        else:
            df_extract[col] = df_extract[col].fillna(df_extract[col].mean())

    start_date = df_extract['Report_Date'].min()
    end_date = df_extract['Report_Date'].max() + pd.Timedelta(days=lookahead_days+30)
    prices = yf.download(ticker, start=start_date, end=end_date, progress=False, auto_adjust=True)["Close"][ticker]

    if get_train:
        df_extract['Price_Ahead'] = df_extract['Report_Date'].apply(
            lambda x: prices.get(x + pd.Timedelta(days=lookahead_days))
        )
        df_extract['Price_Today'] = df_extract['Report_Date'].apply(
            lambda x: prices.get(x)
        )
        df_extract = df_extract.dropna()
        df_extract['Price_Increase'] = (df_extract['Price_Ahead'] > df_extract['Price_Today']).astype(int)
        df_extract = df_extract.drop(columns=['Report_Date', 'Price_Today', 'Price_Ahead'])
    
    else:
        df_extract = df_extract.drop(columns=['Report_Date'])
        df_extract = df_extract.dropna()
    
    return df_extract

def train_fundamentals_model():

    url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    tables = pd.read_html(url, header=0)
    tickers = tables[0]['Symbol'].tolist()

    df_train = pd.DataFrame()
    for ticker in tickers:
        try:
            df_fund = get_fundamentals(ticker, get_train=True, lookahead_days=90)
            if df_fund:
                df_train = pd.concat([df_train, df_fund], ignore_index=True)
        except Exception as e:
            pass
            # print(f"Error processing {ticker}: {e}")

    X = df_train.drop(columns=['Price_Increase'])

    X.replace([np.inf, -np.inf], np.nan, inplace=True)
    X.fillna(X.median(), inplace=True)

    y = df_train['Price_Increase']

    # Define pipeline: scaler + classifier
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('clf', LogisticRegression(random_state=42, max_iter=1000, class_weight='balanced'))
    ])

    # K-Fold Cross Validation
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    accuracies = []

    for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
        
        # Train pipeline
        pipeline.fit(X_train, y_train)
        
        # Predict
        y_pred = pipeline.predict(X_test)
        
        # Evaluate
        acc = accuracy_score(y_test, y_pred)
        accuracies.append(acc)
        
        print(f"Fold {fold} Accuracy: {acc:.4f}")
        print(classification_report(y_test, y_pred, zero_division=0))

    print(f"\nAverage Accuracy across folds: {sum(accuracies)/len(accuracies):.4f}")
    
    pipeline.fit(X, y)
    joblib.dump((pipeline, list(X.columns)), f"./machine_learning/models/fundamentals_model.pkl")

def get_fundamentals_prediction(ticker):
    try:
        model, feature_cols = joblib.load(f"./machine_learning/models/fundamentals_model.pkl")
    except:
        train_fundamentals_model()
        model, feature_cols = joblib.load(f"./machine_learning/models/fundamentals_model.pkl")

    X_test = get_fundamentals(ticker, get_train=False).iloc[[-1]]
    prob = model.predict_proba(X_test)[0, 1]
    decision = "BUY" if prob > 0.5 else "DON'T BUY"

    return decision, prob

# %%
ticker = "TIGR"
# X_test = get_fundamentals(ticker, get_train=False)
decision, prob = get_fundamentals_prediction(ticker)

# %%
decision, prob
# Out:
# ('BUY', np.float64(0.814426148322173))

# %%
X_test
# Out:
#             Gross_Margin  Operating_Margin  Net_Margin  EBITDA_Margin  \
# 2025-03-31      0.680738          0.452799    0.248097       0.459399
# 2024-12-31      0.651430          0.410772    0.226026       0.455949
# 2024-09-30      0.680482          0.412809    0.175691       0.382852
# 2024-06-30      0.640287          0.210527    0.029658       0.250723
# 2024-03-31      0.619776          0.356770    0.156180       0.429724
# 2023-12-31      0.654543          0.368735    0.167130       0.395730
#
#             Revenue_Growth  Net_Income_Growth  EPS_Growth       ROE       ROA  \
# 2025-03-31       -0.101345           0.613973   -0.781818  0.043618  0.004158
# 2024-12-31        0.012168          -0.077874   -0.781818  0.042810  0.004389
# 2024-09-30       -0.185717          -0.367054   -0.363636  0.033034  0.002785
# 2024-06-30       -0.134750          -0.853938   -0.781818  0.005174  0.000541
# 2024-03-31       -0.097082           3.754760   -0.781818  0.024715  0.003083
# 2023-12-31       -0.101345           0.613973   -1.200000  0.029870  0.002991
#
#                 ROIC  Debt_to_Equity  Net_Debt_to_EBITDA  Current_Ratio  \
# 2025-03-31  0.258538        0.246626                 0.0       1.124130
# 2024-12-31  0.265859        0.258780                 0.0       1.137769
# 2024-09-30  0.197297        0.317144                 0.0       1.113821
# 2024-06-30  0.105077        0.340703                 0.0       1.150657
# 2024-03-31  0.160957        0.342842                 0.0       1.184993
# 2023-12-31  0.197545        0.301219                 0.0       1.142274
#
#             Quick_Ratio  FCF_to_Sales  FCF_yield
# 2025-03-31          0.0           0.0        0.0
# 2024-12-31          0.0           0.0        0.0
# 2024-09-30          0.0           0.0        0.0
# 2024-06-30          0.0           0.0        0.0
# 2024-03-31          0.0           0.0        0.0
# 2023-12-31          0.0           0.0        0.0

# %%
t = yf.Ticker(ticker)
inc = t.quarterly_financials.T
bal = t.quarterly_balance_sheet.T
cf  = t.quarterly_cashflow.T

df_raw = pd.concat([inc, bal, cf], axis=1)

# Profitability Ratios
df_extract = pd.DataFrame()

# Profitability Ratios
df_extract['Gross_Margin']      = safe_div(df_raw, 'Gross Profit', 'Total Revenue')
df_extract['Operating_Margin']  = safe_div(df_raw, 'Operating Income', 'Total Revenue')
df_extract['Net_Margin']        = safe_div(df_raw, 'Net Income', 'Total Revenue')
df_extract['EBITDA_Margin']     = safe_div(df_raw, 'EBITDA', 'Total Revenue')

# Growth Ratios (YoY)
df_extract['Revenue_Growth']    = df_raw['Total Revenue'].pct_change(fill_method=None) if 'Total Revenue' in df_raw else np.nan
df_extract['Net_Income_Growth'] = df_raw['Net Income'].pct_change(fill_method=None) if 'Net Income' in df_raw else np.nan
df_extract['EPS_Growth']        = df_raw['Diluted EPS'].pct_change(fill_method=None) if 'Diluted EPS' in df_raw else np.nan

# Return Ratios
df_extract['ROE']   = safe_div(df_raw, 'Net Income', 'Stockholders Equity')
df_extract['ROA']   = safe_div(df_raw, 'Net Income', 'Total Assets')
df_extract['ROIC']  = safe_div(df_raw, 'EBIT', 'Total Debt') + safe_div(df_raw, 'EBIT', 'Stockholders Equity') - safe_div(df_raw, 'EBIT', 'Cash And Cash Equivalents')

# Leverage Ratios
df_extract['Debt_to_Equity']      = safe_div(df_raw, 'Total Debt', 'Stockholders Equity')
df_extract['Net_Debt_to_EBITDA']  = safe_div(df_raw, 'Net Debt', 'EBITDA')

# Liquidity Ratios
df_extract['Current_Ratio'] = safe_div(df_raw, 'Current Assets', 'Current Liabilities')
df_extract['Quick_Ratio']   = safe_div(df_raw, 'Current Assets', 'Current Liabilities') - safe_div(df_raw, 'Inventory', 'Current Liabilities')

# Cash Flow Metrics
df_extract['FCF_to_Sales']  = safe_div(df_raw, 'Free Cash Flow', 'Total Revenue')
df_extract['FCF_yield']     = safe_div(df_raw, 'Free Cash Flow', 'Stockholders Equity')

df_extract['Report_Date'] = df_extract.index

# %%
df_extract
# Out:
#             Gross_Margin  Operating_Margin  Net_Margin  EBITDA_Margin  \
# 2025-03-31      0.680738          0.452799    0.248097       0.459399
# 2024-12-31      0.651430          0.410772    0.226026       0.455949
# 2024-09-30      0.680482          0.412809    0.175691       0.382852
# 2024-06-30      0.640287          0.210527    0.029658       0.250723
# 2024-03-31      0.619776          0.356770    0.156180       0.429724
# 2023-12-31           NaN               NaN         NaN            NaN
#
#             Revenue_Growth  Net_Income_Growth  EPS_Growth       ROE       ROA  \
# 